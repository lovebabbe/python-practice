# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import numpy as np

# %%
s = pd.Series([1,2,3,5,4,5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    5
# 4    4
# 5    5
# dtype: int64

# %%
a = pd.Series(['a','b','c','d'],index=[10,20,30,40])
a
# Out:
# 10    a
# 20    b
# 30    c
# 40    d
# dtype: str

# %%
a[10]
# Out:
# 'a'

# %%
a[40]
# Out:
# 'd'

# %%
#Data Frame
data = {
    "Name": ["Amit", "Riya", "Sohan", "Priya", "Rahul"],
    "Roll Number": [101, 102, 103, 104, 105],
    "Place": ["Delhi", "Mumbai", "Chennai", "Kolkata", "Bangalore"]
}
data
# Out:
# {'Name': ['Amit', 'Riya', 'Sohan', 'Priya', 'Rahul'],
#  'Roll Number': [101, 102, 103, 104, 105],
#  'Place': ['Delhi', 'Mumbai', 'Chennai', 'Kolkata', 'Bangalore']}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Roll Number      Place
# 0   Amit          101      Delhi
# 1   Riya          102     Mumbai
# 2  Sohan          103    Chennai
# 3  Priya          104    Kolkata
# 4  Rahul          105  Bangalore

# %%
df.head(3)
# Out:
#     Name  Roll Number    Place
# 0   Amit          101    Delhi
# 1   Riya          102   Mumbai
# 2  Sohan          103  Chennai

# %%
df.tail(3)
# Out:
#     Name  Roll Number      Place
# 2  Sohan          103    Chennai
# 3  Priya          104    Kolkata
# 4  Rahul          105  Bangalore

# %%
df = df.rename(columns={"Name": "Student_name "})
df
# Out:
#   Student_name   Roll Number      Place
# 0          Amit          101      Delhi
# 1          Riya          102     Mumbai
# 2         Sohan          103    Chennai
# 3         Priya          104    Kolkata
# 4         Rahul          105  Bangalore

# %%
df.drop(columns=["Place"], inplace=True)
df
# Out:
#   Student_name   Roll Number
# 0          Amit          101
# 1          Riya          102
# 2         Sohan          103
# 3         Priya          104
# 4         Rahul          105

# %%
df.set_index("Roll Number",drop = False,inplace=True)

# %%
df
# Out:
#             Student_name   Roll Number
# Roll Number
# 101                  Amit          101
# 102                  Riya          102
# 103                 Sohan          103
# 104                 Priya          104
# 105                 Rahul          105

# %%
import numpy as np

# %%
d = pd.DataFrame ({
    "Days": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"],
    "Place": ["Park", "Mall", np.nan, "Zoo", "Beach"],
    "Visitors": [120, 95, 150, 110, 180]
})

# %%
d
# Out:
#         Days  Place  Visitors
# 0     Monday   Park       120
# 1    Tuesday   Mall        95
# 2  Wednesday    NaN       150
# 3   Thursday    Zoo       110
# 4     Friday  Beach       180

# %%
d.isnull()
# Out:
#     Days  Place  Visitors
# 0  False  False     False
# 1  False  False     False
# 2  False   True     False
# 3  False  False     False
# 4  False  False     False

# %%
d.isnull().sum()
# Out:
# Days        0
# Place       1
# Visitors    0
# dtype: int64

# %%
df.to_csv('to_data.csv')

# %%
load = pd.read_csv('to_data.csv')
load
# Out:
#    Roll Number Student_name   Roll Number.1
# 0          101          Amit            101
# 1          102          Riya            102
# 2          103         Sohan            103
# 3          104         Priya            104
# 4          105         Rahul            285
